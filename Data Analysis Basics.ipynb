# %% [markdown]
# # Numpy

# %%
import numpy as np
arr=np.arange(1,10,2)
print("Element of array:",arr)
arr1=arr[np.array([4,0,2,-1,-2])]
print("Indexed Elements of Array arr:",arr1)
# Out:
# Element of array: [1 3 5 7 9]
# Indexed Elements of Array arr: [9 1 5 9 7]

# %%
nums = [1,2,3,4,5,6,7]
for i in nums:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49

# %%
nums_arry = np.array([1,2,3,4,5,6,7])

# %%
nums_arry**2
# Out:
# array([ 1,  4,  9, 16, 25, 36, 49])

# %%
x=np.arange(0,20,0.2)
y=np.exp(x)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
import pandas as pd

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df[["Ship Mode","Segment"]]
# Out:
#            Ship Mode    Segment
# 0       Second Class   Consumer
# 1       Second Class   Consumer
# 2       Second Class  Corporate
# 3     Standard Class   Consumer
# 4     Standard Class   Consumer
# ...              ...        ...
# 9989    Second Class   Consumer
# 9990  Standard Class   Consumer
# 9991  Standard Class   Consumer
# 9992  Standard Class   Consumer
# 9993    Second Class   Consumer
#
# [9994 rows x 2 columns]

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
print(df["Region"].unique())
print(df["Category"].unique())
print(df["Sub-Category"].unique())
# Out:
# ['South' 'West' 'Central' 'East']
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %% [markdown]
# # EDA

# %%
df["Ship Mode"].value_counts().plot.pie(autopct="%.f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Ship Mode"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
df["Sub-Category"].value_counts().plot.pie(autopct="%.f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sub-Category"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='Sub-Category'>

# %%
df["Sales"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Sales"].plot.hist(xlim=(0,400),bins=1000)
# Out:
# <Axes: ylabel='Frequency'>

# %%
(df[df["Sales"]>300]["Sales"]<350).sum()
# Out:
# 246

# %%
df["Sales"].plot.hist(xlim=(0,100),bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Ship Mode")["Sales"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Sales Analysis

# %%
df.groupby("Segment")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Category")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
import matplotlib.pyplot as plt

# %%
df.groupby("Region").groups
# Out:
# {'Central': [14, 15, 16, 21, 22, 34, 35, 36, 37, 38, 39, 40, 41, 44, 45, 46, 49, 50, 51, 52, 66, 71, 75, 76, 77, 78, 84, 86, 87, 88, 92, 93, 94, 98, 99, 100, 101, 102, 109, 111, 112, 124, 125, 144, 147, 148, 149, 150, 158, 159, 164, 165, 166, 167, 168, 169, 170, 174, 175, 176, 180, 181, 187, 188, 203, 206, 207, 208, 209, 210, 211, 225, 226, 227, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 254, 255, 256, 257, 261, 262, 263, 264, 280, 281, 303, 305, 344, 370, ...], 'East': [23, 27, 28, 29, 30, 31, 32, 33, 47, 48, 53, 54, 55, 56, 57, 58, 59, 60, 61, 70, 96, 110, 113, 114, 115, 116, 119, 120, 121, 122, 123, 130, 131, 132, 140, 146, 161, 177, 178, 179, 185, 189, 190, 191, 192, 193, 195, 196, 197, 198, 199, 200, 212, 213, 214, 215, 216, 219, 220, 221, 222, 223, 224, 252, 253, 258, 259, 260, 267, 268, 269, 276, 277, 278, 279, 289, 290, 291, 292, 298, 299, 300, 301, 302, 304, 306, 307, 313, 316, 317, 318, 319, 320, 321, 326, 327, 328, 329, 330, 331, ...], 'South': [0, 1, 3, 4
# ...

# %%
df.groupby("Region").groups.keys()
# Out:
# dict_keys(['Central', 'East', 'South', 'West'])

# %%
df_west = df.groupby("Region").get_group("West")
df_central = df.groupby("Region").get_group("Central")
df_east = df.groupby("Region").get_group("East")
df_south = df.groupby("Region").get_group("South")

# %%
df_west.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df_west.groupby("Category")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
plt.subplot(2,2,1)
df_west.groupby("Category")["Sales"].sum().plot.bar()
plt.subplot(2,2,2)
df_central.groupby("Category")["Sales"].sum().plot.bar()
plt.subplot(2,2,3)
df_east.groupby("Category")["Sales"].sum().plot.bar()
plt.subplot(2,2,4)
df_south.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
plt.subplot(2,2,1)
df_west.groupby("Category")["Profit"].sum().plot.bar()
plt.subplot(2,2,2)
df_central.groupby("Category")["Profit"].sum().plot.bar()
plt.subplot(2,2,3)
df_east.groupby("Category")["Profit"].sum().plot.bar()
plt.subplot(2,2,4)
df_south.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
plt.subplot(2,2,1)
df_west.groupby("Ship Mode")["Sales"].sum().plot.bar()
plt.subplot(2,2,2)
df_central.groupby("Ship Mode")["Sales"].sum().plot.bar()
plt.subplot(2,2,3)
df_east.groupby("Ship Mode")["Sales"].sum().plot.bar()
plt.subplot(2,2,4)
df_south.groupby("Ship Mode")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
plt.subplot(2,2,1)
df_west.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%.2f%%")
plt.subplot(2,2,2)
df_central.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%.2f%%")
plt.subplot(2,2,3)
df_east.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%.2f%%")
plt.subplot(2,2,4)
df_south.groupby("Ship Mode")["Sales"].sum().plot.pie(autopct="%.2f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# ### Pandas

# %%
df=pd.DataFrame({"Name":["Sakthi","Asif","Gokul","Velu","Deepak","Deva"],
                  "Roll_no":[50,30,18,57,10,12],
                   "Age":[19,19,19,19,19,19],
                 "Marks":[98,99,100,90,98,97]})

# %%
df
# Out:
#      Name  Roll_no  Age  Marks
# 0  Sakthi       50   19     98
# 1    Asif       30   19     99
# 2   Gokul       18   19    100
# 3    Velu       57   19     90
# 4  Deepak       10   19     98
# 5    Deva       12   19     97

# %%
df.describe()
# Out:
#          Roll_no   Age       Marks
# count   6.000000   6.0    6.000000
# mean   29.500000  19.0   97.000000
# std    19.977487   0.0    3.577709
# min    10.000000  19.0   90.000000
# 25%    13.500000  19.0   97.250000
# 50%    24.000000  19.0   98.000000
# 75%    45.000000  19.0   98.750000
# max    57.000000  19.0  100.000000

# %%
import numpy as np
df=pd.DataFrame({"Name":["Sakthi","Asif","Gokul","Velu","Deepak","Deva"],
                  "Roll_no":[50,30,18,57,10,12],
                   "Age":[19,19,19,19,18,19],
                 "Marks":[98,99,np.nan,90,98,np.nan]})

# %%
df
# Out:
#      Name  Roll_no  Age  Marks
# 0  Sakthi       50   19   98.0
# 1    Asif       30   19   99.0
# 2   Gokul       18   19    NaN
# 3    Velu       57   19   90.0
# 4  Deepak       10   18   98.0
# 5    Deva       12   19    NaN

# %%
df.fillna(value="###")
# Out:
#      Name  Roll_no  Age Marks
# 0  Sakthi       50   19  98.0
# 1    Asif       30   19  99.0
# 2   Gokul       18   19   ###
# 3    Velu       57   19  90.0
# 4  Deepak       10   18  98.0
# 5    Deva       12   19   ###

# %%
df.dropna(axis=0,inplace=True)
df
# Out:
#      Name  Roll_no  Age  Marks
# 0  Sakthi       50   19   98.0
# 1    Asif       30   19   99.0
# 3    Velu       57   19   90.0
# 4  Deepak       10   18   98.0

# %%
df["Name"][3]="Gokul"
# Out:
# C:\Users\PERSONAL\AppData\Local\Temp\ipykernel_9424\1959439252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"][3]="Gokul"

# %%
df
# Out:
#      Name  Roll_no  Age  Marks
# 0  Sakthi       50   19   98.0
# 1    Asif       30   19   99.0
# 3   Gokul       57   19   90.0
# 4  Deepak       10   18   98.0

# %%
df
# Out:
#      Name  Roll_no  Age  Marks
# 0  Sakthi       50   19   98.0
# 1    Asif       30   19   99.0
# 3   Gokul       57   19   90.0
# 4  Deepak       10   18   98.0

# %%
df["Age"]=df["Age"].convert_dtypes(convert_integer=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     4 non-null      object
#  1   Roll_no  4 non-null      int64
#  2   Age      4 non-null      Int64
#  3   Marks    4 non-null      float64
# dtypes: Int64(1), float64(1), int64(1), object(1)
# memory usage: 336.0+ bytes

# %%
df.fillna(int(df["Age"].mean()),inplace=True)

# %%
df
# Out:
#      Name  Roll_no  Age  Marks
# 0  Sakthi       50   19   98.0
# 1    Asif       30   19   99.0
# 3   Gokul       57   19   90.0
# 4  Deepak       10   18   98.0

# %%
df["Age"].fillna(value=df["Marks"].mean())
# Out:
# 0    19
# 1    19
# 3    19
# 4    18
# Name: Age, dtype: Int64

# %% [markdown]
# # Exploratory Data Analysis
